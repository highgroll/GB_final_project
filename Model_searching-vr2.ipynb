# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler

from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier

from sklearn.metrics import recall_score, precision_score, accuracy_score, f1_score
from sklearn.metrics import classification_report

# %%
data = pd.read_csv("./Data/audit_data.csv")

# %%
data.head(3)
# Out:
#    Sector_score LOCATION_ID  PARA_A  Score_A  Risk_A  PARA_B  Score_B  Risk_B  \
# 0          3.89          23    4.18      0.6   2.508    2.50      0.2   0.500
# 1          3.89           6    0.00      0.2   0.000    4.83      0.2   0.966
# 2          3.89           6    0.51      0.2   0.102    0.23      0.2   0.046
#
#    TOTAL  numbers  ...  RiSk_E  History  Prob  Risk_F  Score  Inherent_Risk  \
# 0   6.68      5.0  ...     0.4        0   0.2     0.0    2.4          8.574
# 1   4.83      5.0  ...     0.4        0   0.2     0.0    2.0          2.554
# 2   0.74      5.0  ...     0.4        0   0.2     0.0    2.0          1.548
#
#    CONTROL_RISK  Detection_Risk  Audit_Risk  Risk
# 0           0.4             0.5      1.7148     1
# 1           0.4             0.5      0.5108     0
# 2           0.4             0.5      0.3096     0
#
# [3 rows x 27 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 776 entries, 0 to 775
# Data columns (total 27 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Sector_score    776 non-null    float64
#  1   LOCATION_ID     776 non-null    object
#  2   PARA_A          776 non-null    float64
#  3   Score_A         776 non-null    float64
#  4   Risk_A          776 non-null    float64
#  5   PARA_B          776 non-null    float64
#  6   Score_B         776 non-null    float64
#  7   Risk_B          776 non-null    float64
#  8   TOTAL           776 non-null    float64
#  9   numbers         776 non-null    float64
#  10  Score_B.1       776 non-null    float64
#  11  Risk_C          776 non-null    float64
#  12  Money_Value     775 non-null    float64
#  13  Score_MV        776 non-null    float64
#  14  Risk_D          776 non-null    float64
#  15  District_Loss   776 non-null    int64
#  16  PROB            776 non-null    float64
#  17  RiSk_E          776 non-null    float64
#  18  History         776 non-null    int64
#  19  Prob            776 non-null    float64
#  20  Risk_F          776 non-null    float64
#  21  Score           776 non-null    float64
#  22  Inherent_Risk   776 non-null    float64
#  23  CONTROL_RISK    776 non-null    float64
#  24  Detection_Risk  776 non-null    float64
#  25  Audit_Risk      776 non-null    float64
#  26  Risk            776 non-null    int64
# dtypes: float64(23), int64(3), object(1)
# memory usage: 163.8+ KB

# %% [markdown]
# Всего есть 25 признаков и 1 целевая переменная (бинарная) - нужно определить является ли организация мошеннической или нет

# %%
print(data.shape)
# Out:
# (776, 27)

# %% [markdown]
# ###### Всего 776 организаций

# %% [markdown]
# ### Обработка данных

# %%
# Посмотрим на соотношение классов
data.iloc[:, -1].value_counts()
# Out:
# 0    471
# 1    305
# Name: Risk, dtype: int64

# %%
# Помотрим на признаки
data.columns.tolist()
# Out:
# ['Sector_score',
#  'LOCATION_ID',
#  'PARA_A',
#  'Score_A',
#  'Risk_A',
#  'PARA_B',
#  'Score_B',
#  'Risk_B',
#  'TOTAL',
#  'numbers',
#  'Score_B.1',
#  'Risk_C',
#  'Money_Value',
#  'Score_MV',
#  'Risk_D',
#  'District_Loss',
#  'PROB',
#  'RiSk_E',
#  'History',
#  'Prob',
#  'Risk_F',
#  'Score',
#  'Inherent_Risk',
#  'CONTROL_RISK',
#  'Detection_Risk',
#  'Audit_Risk',
#  'Risk']

# %%
# Проверим наличие пропусков в данных
display(data.isna().sum())
# Out:
# Sector_score      0
# LOCATION_ID       0
# PARA_A            0
# Score_A           0
# Risk_A            0
# PARA_B            0
# Score_B           0
# Risk_B            0
# TOTAL             0
# numbers           0
# Score_B.1         0
# Risk_C            0
# Money_Value       1
# Score_MV          0
# Risk_D            0
# District_Loss     0
# PROB              0
# RiSk_E            0
# History           0
# Prob              0
# Risk_F            0
# Score             0
# Inherent_Risk     0
# CONTROL_RISK      0
# Detection_Risk    0
# Audit_Risk        0
# Risk              0
# dtype: int64

# %%
data.corr(method='pearson').style.format("{:.2}").background_gradient(cmap=plt.get_cmap('coolwarm'), axis=1)
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/io/formats/style.py:2813: RuntimeWarning: All-NaN slice encountered
#   smin = np.nanmin(gmap) if vmin is None else vmin
# /usr/local/lib/python3.8/dist-packages/pandas/io/formats/style.py:2814: RuntimeWarning: All-NaN slice encountered
#   smax = np.nanmax(gmap) if vmax is None else vmax
# <style type="text/css">
# #T_aee4e_row0_col0, #T_aee4e_row1_col1, #T_aee4e_row1_col3, #T_aee4e_row2_col2, #T_aee4e_row3_col1, #T_aee4e_row3_col3, #T_aee4e_row4_col4, #T_aee4e_row4_col6, #T_aee4e_row5_col5, #T_aee4e_row6_col4, #T_aee4e_row6_col6, #T_aee4e_row7_col7, #T_aee4e_row8_col8, #T_aee4e_row9_col9, #T_aee4e_row10_col10, #T_aee4e_row11_col11, #T_aee4e_row11_col13, #T_aee4e_row12_col12, #T_aee4e_row13_col11, #T_aee4e_row13_col13, #T_aee4e_row14_col14, #T_aee4e_row15_col15, #T_aee4e_row16_col16, #T_aee4e_row17_col17, #T_aee4e_row18_col18, #T_aee4e_row19_col19, #T_aee4e_row20_col20, #T_aee4e_row21_col21, #T_aee4e_row22_col22, #T_aee4e_row24_col24, #T_aee4e_row25_col25 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_aee4e_row0_col1, #T_aee4e_row0_col3, #T_aee4e_row0_col5, #T_aee4e_row14_col15, #T_aee4e_row15_col24 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_aee4e_row0_col2, #T_aee4e_row1_col0, #T_aee4e_row2_col0, #T_aee4e_row3_col0, #T_aee4e_row4_col0, #T_aee4e_row5_col0, #T_aee4e_row6_col0, #T_aee4e_row7_col0, #T_aee4e_row8_col0, #T_aee4e_row9_col0, #T_aee4e_row10_col0, #T_aee4e_row11_col0, #T_aee4e_row12_col0, #T_aee4e_row13_col0, #T_aee4e_row14_col0, #T_aee4e_row15_col0, #T_aee4e_row16_col0, #T_aee4e_row17_col0, #T_aee4e_row18_col0, #T_aee4e_row19_col0, #T_aee4e_row20_col0, #T_aee4e_row21_col0, #T_aee4e_row22_col0, #T_aee4e_row24_col0, #T_aee4e_row25_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_aee4e_row0_col4, #T_aee4e_row0_col6, #T_aee4e_row11_col18, #T_aee4e_row13_col18, #T_aee4e_row16_col2, #T_aee4e_row16_col12 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_aee4e_row0_col7, #T_aee4e_row0_col22, #T_aee4e_row4_col14, #T_aee4e_row6_col14, #T_aee4e_row19_col1, #T_aee4e_row19_col3, #T_aee4e_row19_col15 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_aee4e_row0_col8, #T_aee4e_row5_col16, #T_aee4e_row16_col7, #T_aee4e_row18_col14, #T_aee4e_row19_col16, #T_aee4e_row21_col15, #T_aee4e_row22_col11, #T_aee4e_row22_col13 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_aee4e_row0_col9, #T_aee4e_row0_col21, #T_aee4e_row5_col14, #T_aee4e_row9_col15, #T_aee4e_row11_col17, #T_aee4e_row14_col2, #T_aee4e_row15_col19 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_aee4e_row0_col10, #T_aee4e_row14_col7, #T_aee4e_row15_col17 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_aee4e_row0_col11, #T_aee4e_row0_col13, #T_aee4e_row0_col17, #T_aee4e_row3_col15, #T_aee4e_row11_col4, #T_aee4e_row11_col6, #T_aee4e_row13_col4, #T_aee4e_row13_col6, #T_aee4e_row18_col13, #T_aee4e_row21_col14, #T_aee4e_row21_col16 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_aee4e_row0_col12 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_aee4e_row0_col14, #T_aee4e_row16_col1, #T_aee4e_row16_col3, #T_aee4e_row18_col11 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_aee4e_row0_col15, #T_aee4e_row16_col8 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_aee4e_row0_col16, #T_aee4e_row7_col16, #T_aee4e_row14_col8, #T_aee4e_row15_col18, #T_aee4e_row17_col1 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_aee4e_row0_col18, #T_aee4e_row15_col12, #T_aee4e_row17_col15, #T_aee4e_row17_col16 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_aee4e_row0_col19, #T_aee4e_row6_col11, #T_aee4e_row6_col13, #T_aee4e_row16_col18 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_aee4e_row0_col20 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_aee4e_row0_col23, #T_aee4e_row1_col23, #T_aee4e_row2_col23, #T_aee4e_row3_col23, #T_aee4e_row4_col23, #T_aee4e_row5_col23, #T_aee4e_row6_col23, #T_aee4e_row7_col23, #T_aee4e_row8_col23, #T_aee4e_row9_col23, #T_aee4e_row10_col23, #T_aee4e_row11_col23, #T_aee4e_row12_col23, #T_aee4e_row13_col23, #T_aee4e_row14_col23, #T_aee4e_row15_col23, #T_aee4e_row16_col23, #T_aee4e_row17_col23, #T_aee4e_row18_col23, #T_aee4e_row19_col23, #T_aee4e_row20_col23, #T_aee4e_row21_col23, #T_aee4e_row22_col23, #T_aee4e_row23_col0, #T_aee4e_row23_col1, #T_aee4e_row23_col2, #T_aee4e_row23_col3, #T_aee4e_row23_col4, #T_aee4e_row23_col5, #T_aee4e_row23_col6, #T_aee4e_row23_col7, #T_aee4e_row23_col8, #T_aee4e_row23_col9, #T_aee4e_row23_col10, #T_aee4e_row23_col11, #T_aee4e_row23_col12, #T_aee4e_row23_col13, #T_aee4e_row23_col14, #T_aee4e_row23_col15, #T_aee4e_row23_col16, #T_aee4e_row23_col17, #T_aee4e_row23_col18, #T_aee4e_row23_col19, #T_aee4e_row23_col20, #T_aee4e_row23_col21, #T_aee4e_row23_col22, #T_aee4e_row23_col23, #T_aee4e_row23_col24, #T_aee4e_row23_col25, #T_aee4e_row24_col23, #T_aee4e_row25_col23 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_aee4e_row0_col24, #T_aee4e_row14_col9, #T_aee4e_row15_col20 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_aee4e_row0_col25 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_aee4e_row1_col2 {
#   background-color: #f0cdbb;
#   color: #000000;
# }
# #T_aee4e_row1_col4, #T_aee4e_row1_col6 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_aee4e_row1_col5, #T_aee4e_row2_col4, #T_aee4e_row5_col1, #T_aee4e_row16_col15 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_aee4e_row1_col7, #T_aee4e_row4_col12, #T_aee4e_row4_col18, #T_aee4e_row6_col18, #T_aee4e_row17_col20 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_aee4e_row1_col8, #T_aee4e_row6_col19, #T_aee4e_row11_col5, #T_aee4e_row13_col2, #T_aee4e_row13_col5, #T_aee4e_row14_col20, #T_aee4e_row17_col4, #T_aee4e_row19_col25, #T_aee4e_row24_col1, #T_aee4e_row24_col3, #T_aee4e_row24_col8 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_aee4e_row1_col9, #T_aee4e_row1_col10, #T_aee4e_row3_col10, #T_aee4e_row4_col17, #T_aee4e_row6_col17, #T_aee4e_row8_col11, #T_aee4e_row8_col13, #T_aee4e_row16_col24, #T_aee4e_row19_col9, #T_aee4e_row21_col19, #T_aee4e_row21_col22, #T_aee4e_row22_col4, #T_aee4e_row22_col6 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_aee4e_row1_col11, #T_aee4e_row3_col11, #T_aee4e_row3_col13, #T_aee4e_row20_col4, #T_aee4e_row20_col6 {
#   background-color: #e9d5cb;
#   color: #000000;
# }
# #T_aee4e_row1_col12, #T_aee4e_row9_col5, #T_aee4e_row21_col9, #T_aee4e_row24_col22 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# #T_aee4e_row1_col13, #T_aee4e_row21_col20 {
#   background-color: #e8d6cc;
#   color: #000000;
# }
# #T_aee4e_row1_col14, #T_aee4e_row3_col14, #T_aee4e_row4_col22, #T_aee4e_row5_col22, #T_aee4e_row17_col5, #T_aee4e_row17_col6, #T_aee4e_row17_col8, #T_aee4e_row22_col2, #T_aee4e_row22_col21, #T_aee4e_row24_col25 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_aee4e_row1_col15, #T_aee4e_row7_col14, #T_aee4e_row14_col1, #T_aee4e_row14_col3, #T_aee4e_row16_col17, #T_aee4e_row16_col19, #T_aee4e_row17_col3 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_aee4e_row1_col16, #T_aee4e_row1_col17, #T_aee4e_row3_col16, #T_aee4e_row9_col14, #T_aee4e_row10_col16, #T_aee4e_row18_col3, #T_aee4e_row19_col7, #T_aee4e_row19_col8, #T_aee4e_row24_col5 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_aee4e_row1_col18, #T_aee4e_row5_col19, #T_aee4e_row6_col9, #T_aee4e_row17_col25 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_aee4e_row1_col19, #T_aee4e_row4_col3, #T_aee4e_row10_col1, #T_aee4e_row10_col3, #T_aee4e_row17_col2, #T_aee4e_row22_col1, #T_aee4e_row22_col3 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_aee4e_row1_col20, #T_aee4e_row25_col10 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_aee4e_row1_col21, #T_aee4e_row20_col1, #T_aee4e_row25_col14 {
#   background-color: #edd1c2;
#   color: #000000;
# }
# #T_aee4e_row1_col22, #T_aee4e_row3_col22, #T_aee4e_row4_col8, #T_aee4e_row6_col8, #T_aee4e_row7_col22, #T_aee4e_row11_col9, #T_aee4e_row12_col14, #T_aee4e_row13_col9, #T_aee4e_row17_col10 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_aee4e_row1_col24, #T_aee4e_row9_col18, #T_aee4e_row10_col22, #T_aee4e_row10_col24, #T_aee4e_row22_col9 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_aee4e_row1_col25, #T_aee4e_row2_col9, #T_aee4e_row5_col7, #T_aee4e_row25_col7 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_aee4e_row2_col1, #T_ae

# %%
# Выделим целевую пересенную
# Переменные TOTAL , LOCATION_ID и Detection_Risk исключаем из списка, т.к. TOTAL есть сумма признаков PARA_A и 
# PARA_B, а LOCATION_ID и Detection_Risk не оказывают сильного влияния на прдсказание целевой переменной. 
# Risk_A и Risk_B похоже на PARA_A','PARA_B -убираем
# District_Loss - убираем, после нормализации у него большие значения

feature_names = ['Sector_score', 'Score_A', 'PARA_A', 'Score_B', 'PARA_B', 'numbers',
                 'Score_B.1','Risk_C', 'Money_Value', 'Score_MV', 'PROB', 'RiSk_E', 'Risk_D',
                 'History', 'Prob', 'Risk_F', 'Score', 'Inherent_Risk', 'CONTROL_RISK', 'Audit_Risk']

target_name = 'Risk'

# %%
data = data[feature_names + [target_name]]
data.head(2)
# Out:
#    Sector_score  Score_A  PARA_A  Score_B  PARA_B  numbers  Score_B.1  Risk_C  \
# 0          3.89      0.6    4.18      0.2    2.50      5.0        0.2     1.0
# 1          3.89      0.2    0.00      0.2    4.83      5.0        0.2     1.0
#
#    Money_Value  Score_MV  ...  RiSk_E  Risk_D  History  Prob  Risk_F  Score  \
# 0         3.38       0.2  ...     0.4   0.676        0   0.2     0.0    2.4
# 1         0.94       0.2  ...     0.4   0.188        0   0.2     0.0    2.0
#
#    Inherent_Risk  CONTROL_RISK  Audit_Risk  Risk
# 0          8.574           0.4      1.7148     1
# 1          2.554           0.4      0.5108     0
#
# [2 rows x 21 columns]

# %%
def preprocesing(df):
    
    # Уберём пропуски в данных
    df['Money_Value'] = df['Money_Value'].fillna(df['Money_Value'].mean()) 
    
    # Стандартизируем признаки
    feature_names_for_stand = df[feature_names].select_dtypes(include=['float64']).columns.tolist()

    scaler = StandardScaler()
    stand_features = scaler.fit_transform(df[feature_names_for_stand])

    df[feature_names_for_stand] = pd.DataFrame(stand_features, columns=feature_names_for_stand)
    
    # Разбиваем данные
    X_data = df.iloc[:,:-1]
    y_data = df.iloc[:,-1]

    X_train, X_test, y_train, y_test = train_test_split(X_data, y_data, test_size=0.30, random_state=42)
    
    return X_train, X_test, y_train, y_test

# %%
X_train, X_test, y_train, y_test = preprocesing(data)

# %%
X_train.head(3)
# Out:
#      Sector_score   Score_A    PARA_A   Score_B    PARA_B   numbers  \
# 335     -0.733008 -0.869761 -0.431736 -0.666752 -0.215778 -0.255998
# 110     -0.670465  1.429846  0.031683 -0.666752 -0.164831 -0.255998
# 82      -0.670465 -0.869761 -0.431736 -0.666752 -0.215778 -0.255998
#
#      Score_B.1    Risk_C  Money_Value  Score_MV     PROB    RiSk_E   Risk_D  \
# 335  -0.295285 -0.284812     -0.21253 -0.569895 -0.16502 -0.410417 -0.20692
# 110  -0.295285 -0.284812     -0.21253 -0.569895 -0.16502 -0.410417 -0.20692
# 82   -0.295285 -0.284812     -0.21253 -0.569895 -0.16502 -0.410417 -0.20692
#
#      History      Prob    Risk_F     Score  Inherent_Risk  CONTROL_RISK  \
# 335        0 -0.246568 -0.175398 -0.818503      -0.297608     -0.388662
# 110        0 -0.246568 -0.175398 -0.352503      -0.259439     -0.388662
# 82         0 -0.246568 -0.175398 -0.818503      -0.297608     -0.388662
#
#      Audit_Risk
# 335   -0.178253
# 110   -0.167446
# 82    -0.178253

# %%
y_train.head(3)
# Out:
# 335    0
# 110    0
# 82     0
# Name: Risk, dtype: int64

# %% [markdown]
# ### Обучаем несколько моделей

# %%
models = {    
    "Gradient Boosting": GradientBoostingClassifier(),
    "K-Nearest Neighbors": KNeighborsClassifier(),   
    "Random Forest": RandomForestClassifier(),
    "Decision Tree": DecisionTreeClassifier()    
}

# %%
for name, model in models.items():
    model.fit(X_train, y_train)
    print(name + " trained.")
# Out:
# Gradient Boosting trained.
# K-Nearest Neighbors trained.
# Random Forest trained.
# Decision Tree trained.

# %%
for name, model in models.items():
    print(name + ": {:.2f}%".format(model.score(X_test, y_test) * 100))
# Out:
# Gradient Boosting: 100.00%
# K-Nearest Neighbors: 95.28%
# Random Forest: 100.00%
# Decision Tree: 100.00%

# %%
for name, model in models.items():    
    print('Classification results:', name)
    y_predict = model.predict(X_test)   
    accuracy = accuracy_score(y_test, y_predict)
    print("accuracy: %.2f%%" % (accuracy * 100.0))
    f1 = f1_score(y_test, y_predict)
    print("f1: %.2f%%" % (f1 * 100.0))    
    rec = recall_score(y_test, y_predict, average='binary')
    print("recall: %.2f%%" % (rec * 100.0))
    prc = precision_score(y_test, y_predict, average='binary')
    print("precision: %.2f%%" % (prc * 100.0))
# Out:
# Classification results: Gradient Boosting
# accuracy: 100.00%
# f1: 100.00%
# recall: 100.00%
# precision: 100.00%
# Classification results: K-Nearest Neighbors
# accuracy: 95.28%
# f1: 93.71%
# recall: 89.13%
# precision: 98.80%
# Classification results: Random Forest
# accuracy: 100.00%
# f1: 100.00%
# recall: 100.00%
# precision: 100.00%
# Classification results: Decision Tree
# accuracy: 100.00%
# f1: 100.00%
# recall: 100.00%
# precision: 100.00%

# %%
for name, model in models.items():    
    report = classification_report(y_test, model.predict(X_test), target_names=['Fraud', 'No Fraud'])
    print('Model:', name)    
    print(report)
# Out:
# Model: Gradient Boosting
#               precision    recall  f1-score   support
#
#        Fraud       1.00      1.00      1.00       141
#     No Fraud       1.00      1.00      1.00        92
#
#     accuracy                           1.00       233
#    macro avg       1.00      1.00      1.00       233
# weighted avg       1.00      1.00      1.00       233
#
# Model: K-Nearest Neighbors
#               precision    recall  f1-score   support
#
#        Fraud       0.93      0.99      0.96       141
#     No Fraud       0.99      0.89      0.94        92
#
#     accuracy                           0.95       233
#    macro avg       0.96      0.94      0.95       233
# weighted avg       0.95      0.95      0.95       233
#
# Model: Random Forest
#               precision    recall  f1-score   support
#
#        Fraud       1.00      1.00      1.00       141
#     No Fraud       1.00      1.00      1.00        92
#
#     accuracy                           1.00       233
#    macro avg       1.00      1.00      1.00       233
# weighted avg       1.00      1.00      1.00       233
#
# Model: Decision Tree
#               precision    recall  f1-score   support
#
#        Fraud       1.00      1.00      1.00       141
#     No Fraud       1.00      1.00      1.00        92
#
#     accuracy                           1.00       233
#    macro avg       1.00      1.00      1.00       233
# weighted avg       1.00      1.00      1.00       233
